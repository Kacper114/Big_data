# %% [markdown]
# # Zadanie z zajęć 1 - Analiza danych o krajach świata
#
# Notebook uruchamia rozwiązanie z pliku `zadanie_zajecia_1.py`. Skrypt wykonuje cały pipeline: API -> DataFrame -> SQLite -> analiza SQL -> wizualizacja.

# %% [markdown]
# ## Instalacja bibliotek
#
# Jeśli środowisko nie ma jeszcze bibliotek, uruchom w terminalu:
#
# ```powershell
# uv add pandas requests matplotlib
# ```
#
# albo klasycznie:
#
# ```powershell
# pip install -r requirements.txt
# ```

# %%
# %run zadanie_zajecia_1.py
