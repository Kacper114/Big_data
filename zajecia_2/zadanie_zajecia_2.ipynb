# %% [markdown]
# # Zadanie z zajęć 2 - Czyszczenie danych e-commerce
#
# Ten notebook uruchamia rozwiązanie z pliku `zadanie_zajecia_2.py`. Skrypt generuje brudne dane, czyści je, robi analizę i zapisuje wynikowe pliki.

# %% [markdown]
# ## Problemy w danych
#
# W danych występują m.in. duplikaty, braki danych, różne formaty dat, ceny zapisane jako tekst, niespójna wielkość liter w kategoriach i błędne ilości zamówionych produktów. Wszystko jest czyszczone w skrypcie.

# %%
# %run zadanie_zajecia_2.py
